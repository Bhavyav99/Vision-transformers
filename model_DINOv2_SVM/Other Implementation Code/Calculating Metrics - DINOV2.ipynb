# %%
ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)

# %% [markdown]
# # PART A

# %%
TP = 595
FP = 1
FN = 0
TN = 176

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 

F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)

omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)

print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9983221476510067
# Precision-NOK 1.0
# Recall-Ok 1.0
# Recall-NOk 0.9943502824858758
# F1_ok 0.9986572675394427
# F1_Nok 0.9960818458859382
# omission_ok 0.0016778523489932886
# omission_nok 0.0

# %% [markdown]
# # PART B

# %%
TP = 598
FP = 55
FN = 1
TN = 135

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 

F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)

omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9157733537519143
# Precision-NOK 0.9926470588235294
# Recall-Ok 0.998330550918197
# Recall-NOk 0.7105263157894737
# F1_ok 0.9311740890688258
# F1_Nok 0.7786157941437445
# omission_ok 0.08422664624808576
# omission_nok 0.007352941176470588

# %% [markdown]
# # PART C

# %%
TP = 597
FP = 44
FN = 0
TN = 145

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 

F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)

omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)

print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9313572542901716
# Precision-NOK 1.0
# Recall-Ok 1.0
# Recall-NOk 0.7671957671957672
# F1_ok 0.9443214172730149
# F1_Nok 0.8263919333625602
# omission_ok 0.0686427457098284
# omission_nok 0.0

# %% [markdown]
# # PART D

# %%
TP = 597
FP = 14
FN = 1
TN = 172

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9770867430441899
# Precision-NOK 0.9942196531791907
# Recall-Ok 0.9983277591973244
# Recall-NOk 0.9247311827956989
# F1_ok 0.9812623274161736
# F1_Nok 0.9450549450549451
# omission_ok 0.022913256955810146
# omission_nok 0.005780346820809248

# %% [markdown]
# # PART E

# %%
TP = 298
FP = 17
FN = 0
TN = 73

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.946031746031746
# Precision-NOK 1.0
# Recall-Ok 1.0
# Recall-NOk 0.8111111111111111
# F1_ok 0.956354300385109
# F1_Nok 0.8611615245009074
# omission_ok 0.05396825396825397
# omission_nok 0.0

# %% [markdown]
# # PART F

# %%
TP = 595
FP = 2
FN = 1
TN = 186

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 

F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)

omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9966499162479062
# Precision-NOK 0.9946524064171123
# Recall-Ok 0.9983221476510067
# Recall-NOk 0.9893617021276596
# F1_ok 0.9969839142091153
# F1_Nok 0.990983606557377
# omission_ok 0.0033500837520938024
# omission_nok 0.0053475935828877

# %% [markdown]
# # PART G

# %%
TP = 599
FP = 63
FN = 0
TN = 123

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.904833836858006
# Precision-NOK 1.0
# Recall-Ok 1.0
# Recall-NOk 0.6612903225806451
# F1_ok 0.922389898367724
# F1_Nok 0.7382271468144044
# omission_ok 0.09516616314199396
# omission_nok 0.0

# %% [markdown]
# # PART H

# %%
TP = 599
FP = 67
FN = 0
TN = 108

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 

F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)

omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)

print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.8993993993993994
# Precision-NOK 1.0
# Recall-Ok 1.0
# Recall-NOk 0.6171428571428571
# F1_ok 0.9178669935642048
# F1_Nok 0.6995515695067265
# omission_ok 0.1006006006006006
# omission_nok 0.0

# %% [markdown]
# # PART I

# %%
TP = 596
FP = 19
FN = 1
TN = 147

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 

F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)

omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)

print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9691056910569106
# Precision-NOK 0.9932432432432432
# Recall-Ok 0.998324958123953
# Recall-NOk 0.8855421686746988
# F1_ok 0.9748119070984627
# F1_Nok 0.9161073825503355
# omission_ok 0.030894308943089432
# omission_nok 0.006756756756756757

# %% [markdown]
# # ALL PARTS

# %%
TP = 5073
FP = 319
FN = 5
TN = 1228

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 

F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)

omission_ok = FP / ( TP + FP) 
omission_nok = FN / (TN+ FN)

print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9408382789317508
# Precision-NOK 0.9959448499594485
# Recall-Ok 0.9990153603781016
# Recall-NOk 0.7937944408532643
# F1_ok 0.9519252420625984
# F1_Nok 0.8466719702996554
# omission_ok 0.05916172106824926
# omission_nok 0.0040551500405515
