# %%
ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)

# %% [markdown]
# # PART A

# %%
TP = 595
FN = 1
FP = 0
TN = 176

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 1.0
# Precision-NOK 0.9943502824858758
# Recall-Ok 0.9983221476510067
# Recall-NOk 1.0
# F1_ok 0.9996639784946237
# F1_Nok 0.9982547993019196
# omission_ok 0.0
# omission_nok 0.0016778523489932886

# %% [markdown]
# # PART B

# %%
TP = 598
FN = 55
FP = 1
TN = 135

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.998330550918197
# Precision-NOK 0.7105263157894737
# Recall-Ok 0.9157733537519143
# Recall-NOk 0.9926470588235294
# F1_ok 0.9806493932436866
# F1_Nok 0.8845766129032259
# omission_ok 0.007352941176470588
# omission_nok 0.08422664624808576

# %% [markdown]
# # PART C

# %%
TP = 597
FN = 44
FP = 0
TN = 145

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 1.0
# Precision-NOK 0.7671957671957672
# Recall-Ok 0.9313572542901716
# Recall-NOk 1.0
# F1_ok 0.985473753714097
# F1_Nok 0.9146045608927704
# omission_ok 0.0
# omission_nok 0.0686427457098284

# %% [markdown]
# # PART D

# %%
TP = 597
FN = 14
FP = 1
TN = 172

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9983277591973244
# Precision-NOK 0.9247311827956989
# Recall-Ok 0.9770867430441899
# Recall-NOk 0.9942196531791907
# F1_ok 0.9940059940059941
# F1_Nok 0.9717514124293787
# omission_ok 0.005780346820809248
# omission_nok 0.022913256955810146

# %% [markdown]
# # PART E

# %%
TP = 298
FN = 17
FP = 0
TN = 73

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 1.0
# Precision-NOK 0.8111111111111111
# Recall-Ok 0.946031746031746
# Recall-NOk 1.0
# F1_ok 0.9887193098871931
# F1_Nok 0.9331366764995083
# omission_ok 0.0
# omission_nok 0.05396825396825397

# %% [markdown]
# # PART F

# %%
TP = 595
FN = 2
FP = 1
TN = 186

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9983221476510067
# Precision-NOK 0.9893617021276596
# Recall-Ok 0.9966499162479062
# Recall-NOk 0.9946524064171123
# F1_ok 0.9979872525997987
# F1_Nok 0.9930184804928132
# omission_ok 0.0053475935828877
# omission_nok 0.0033500837520938024

# %% [markdown]
# # PART G

# %%
TP = 599
FN = 63
FP = 0
TN = 123

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 1.0
# Precision-NOK 0.6612903225806451
# Recall-Ok 0.904833836858006
# Recall-NOk 1.0
# F1_ok 0.9793982995421844
# F1_Nok 0.8638573743922203
# omission_ok 0.0
# omission_nok 0.09516616314199396

# %% [markdown]
# # PART H

# %%
TP = 599
FN = 67
FP = 0
TN = 108

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 1.0
# Precision-NOK 0.6171428571428571
# Recall-Ok 0.8993993993993994
# Recall-NOk 1.0
# F1_ok 0.9781188765512737
# F1_Nok 0.8397129186602871
# omission_ok 0.0
# omission_nok 0.1006006006006006

# %% [markdown]
# # PART I

# %%
TP = 596
FN = 19
FP = 1
TN = 147

ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.998324958123953
# Precision-NOK 0.8855421686746988
# Recall-Ok 0.9691056910569106
# Recall-NOk 0.9932432432432432
# F1_ok 0.9923409923409922
# F1_Nok 0.9574148296593187
# omission_ok 0.006756756756756757
# omission_nok 0.030894308943089432

# %% [markdown]
# # ALL PARTS

# %%
TP = 5084
FN = 322
FP = 16
TN = 1230




ok_precision = TP/ (TP+FP) 
nok_precision = TN / (TN + FN) 

ok_recall = TP / (TP + FN )
nok_recall = TN / (TN + FP) 


F1_ok = ((1 + (0.5 * 0.5)) * ok_precision * ok_recall) / (((0.5 * 0.5) * ok_precision) + ok_recall)
F1_nok = ((1 + (1.5 * 1.5)) * nok_precision * nok_recall) / (((1.5 * 1.5) * nok_precision) + nok_recall)


omission_ok = FP / ( TN + FP) 
omission_nok = FN / (TP+ FN)


print("Precision-OK", ok_precision)
print("Precision-NOK", nok_precision)

print("Recall-Ok", ok_recall)
print("Recall-NOk", nok_recall)

print("F1_ok", F1_ok)
print("F1_Nok", F1_nok)

print("omission_ok", omission_ok)
print("omission_nok", omission_nok)
# Out:
# Precision-OK 0.9968627450980392
# Precision-NOK 0.7925257731958762
# Recall-Ok 0.9404365519792823
# Recall-NOk 0.9871589085072231
# F1_ok 0.9850422382391693
# F1_Nok 0.9178050740443118
# omission_ok 0.012841091492776886
# omission_nok 0.059563448020717724
