# %%
import cv2
import os
from PIL import Image
import os

# %%
DATA_DIR = 'C:/Users/resu/Desktop/Project - II Final Submission/Fangjun_Wang_2021_MBH-dataset/MBH-dataset/'

# %%
with open(DATA_DIR + "test.txt") as f:
    lines = [line for line in f]

# %%
lines
# Out:
# ['0541@View-001@2020-12-1_11-51-55.jpg_Part-0002.jpg Part-0002 0\n',
#  '1905@View-001@2020-12-7_15-41-14.jpg_Part-0002.jpg Part-0002 0\n',
#  '0578@View-001@2020-10-23_9-38-32.jpg_Part-0002.jpg Part-0002 0\n',
#  '0592@View-001@2020-12-1_14-47-59.jpg_Part-0002.jpg Part-0002 0\n',
#  '1888@View-001@2020-12-7_15-37-19.jpg_Part-0002.jpg Part-0002 0\n',
#  '0397@View-001@2020-11-28_16-21-47.jpg_Part-0002.jpg Part-0002 0\n',
#  '0392@View-001@2020-11-28_16-20-18.jpg_Part-0002.jpg Part-0002 0\n',
#  '0930@View-001@2020-12-7_8-06-08.jpg_Part-0002.jpg Part-0002 0\n',
#  '1154@View-001@2020-12-7_9-19-22.jpg_Part-0002.jpg Part-0002 0\n',
#  '0125@View-001@2020-10-6_10-41-11.jpg_Part-0002.jpg Part-0002 0\n',
#  '1898@View-001@2020-12-7_15-39-44.jpg_Part-0002.jpg Part-0002 0\n',
#  '0228@View-001@2020-10-10_9-34-24.jpg_Part-0002.jpg Part-0002 0\n',
#  '0464@View-001@2020-10-23_8-59-19.jpg_Part-0002.jpg Part-0002 0\n',
#  '1329@View-001@2020-12-7_12-04-37.jpg_Part-0002.jpg Part-0002 0\n',
# ...

# %%
len(lines)
# Out:
# 6800

# %%
image_folder = "Part-0018"
new_lines = []

for i in range(len(lines)):
    temp = str(lines[i]).split()
    img_name = temp[0] 
    img_folder = temp[1]
    label = temp[2]
    
    #print(img_name)
    #print(img_folder)
    #print(label)
    
    if img_folder == image_folder:
        new_lines.append(lines[i])

# %%
image_folder = "Part-0021"

for i in range(len(lines)):
    temp = str(lines[i]).split()
    img_name = temp[0] 
    img_folder = temp[1]
    label = temp[2]
    
    #print(img_name)
    #print(img_folder)
    #print(label)
    
    if img_folder == image_folder:
        new_lines.append(lines[i])

# %%
new_lines
# Out:
# ['1726@View-002@2020-12-7_14-37-46.jpg_Part-0018.jpg Part-0018 0\n',
#  '0146@View-002@2020-10-6_10-53-33.jpg_Part-0018.jpg Part-0018 0\n',
#  '0181@View-002@2020-10-10_9-04-52.jpg_Part-0018.jpg Part-0018 0\n',
#  '0163@View-002@2020-11-24_13-24-18.jpg_Part-0018.jpg Part-0018 0\n',
#  '0480@View-002@2020-10-23_9-04-57.jpg_Part-0018.jpg Part-0018 0\n',
#  '0636@View-002@2020-10-24_14-57-55.jpg_Part-0018.jpg Part-0018 0\n',
#  '1260@View-002@2020-11-17_11-16-26.jpg_Part-0018.jpg Part-0018 0\n',
#  '1490@View-002@2020-12-7_12-56-36.jpg_Part-0018.jpg Part-0018 0\n',
#  '0514@View-002@2020-10-23_9-15-21.jpg_Part-0018.jpg Part-0018 0\n',
#  '0697@View-002@2020-12-4_9-34-43.jpg_Part-0018.jpg Part-0018 0\n',
#  '0439@View-002@2020-11-28_16-58-24.jpg_Part-0018.jpg Part-0018 0\n',
#  '0984@View-002@2020-12-7_8-29-37.jpg_Part-0018.jpg Part-0018 0\n',
#  '0258@View-002@2020-10-10_9-48-34.jpg_Part-0018.jpg Part-0018 0\n',
#  '1134@View-002@2020-12-7_9-13-49.jpg_Part-0018.jpg Part-0018 0\n',
# ...

# %%
len(new_lines)
# Out:
# 800

# %%
path = 'C:/Users/resu/Desktop/FAPS - AI Project/datasets/Fangjun_Wang_2021_MBH-dataset/MBH-dataset/Data_Exploration/A/'


count_ok = 0 
count_nok = 0 

for i in range(len(new_lines)):
    temp = str(new_lines[i]).split()
    img_name = temp[0] 
    img_folder = temp[1]
    label = temp[2]
    label = int(label)
    
    #print(img_name)
    #print(img_folder)
    #print(label)
    
    if label == 0:
        count_ok+=1
    else:
        count_nok+=1 
    
    '''image_path = DATA_DIR + "total_data/"+ str(img_folder) + "/"+ img_name

    img = cv2.imread(image_path) 

    
    path_0 = os.path.join(path, "0") 
    path_1 = os.path.join(path, "1")
    
    #print(path_0)
    if not os.path.exists(path_0):
        os.makedirs(path_0)
        #print("created")
        
    if not os.path.exists(path_1):
        os.makedirs(path_1)
        #print("created")
    
    if label == 0:
        #print("entered")
        cv2.imwrite(os.path.join(path_0 , img_name), img)
        #print("done")
        #cv2.waitKey(0)
    else: 
        cv2.imwrite(os.path.join(path_1, img_name), img)
        #print("done - 2")
        #cv2.waitKey(0)'''

# %%
count_ok
# Out:
# 600

# %%
count_nok
# Out:
# 200
