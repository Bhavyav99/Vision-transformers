# %%
import torch

import random
torch.manual_seed(17)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)


DATA_DIR = f'/home/woody/iwfa/iwfa011h/Fangjun_Wang_2021_MBH-dataset/MBH-dataset/Labels/Main_Labels/'

lines = []
## Training Test
with open(DATA_DIR + "train.txt") as f:
    lines = [line for line in f]

print("train dataset: ", len(lines))

### getting only Part A training data

train_lines = []
train_ok = []
train_nok = []

j = 0
temp = []
temp1 = []
temp2 = []
while (j <=8):
    for i in range(len(lines)):
        temp_str = str(lines[i]).split()
        img_name = temp_str[0]
        img_folder = temp_str[1]
        label = int(temp_str[2])

        # print(img_name)
        # print(img_folder)
        # print(label)
        if j==0:
            if img_folder == "Part-0002" or img_folder == "Part-0003":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j ==1:
            if img_folder == "Part-0004" or img_folder == "Part-0005":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==2:
            if img_folder == "Part-0006" or img_folder == "Part-0007":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j ==3:
            if img_folder == "Part-0012" or img_folder == "Part-0013":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==4:
            if img_folder == "Part-0014":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==5:
            if img_folder == "Part-0015" or img_folder == "Part-0016":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==6:
            if img_folder == "Part-0017" or img_folder == "Part-0020":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==7:
            if img_folder == "Part-0018" or img_folder == "Part-0021":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==8:
            if img_folder == "Part-0019" or img_folder == "Part-0022":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])

    train_lines.append(len(temp))
    train_ok.append(len(temp1))
    train_nok.append(len(temp2))
    j+=1
    temp = []
    temp1 = []
    temp2=[]


print("Training Dataset for all the parts: ", train_lines)
print("Training Dataset (OK) for all the parts: ", train_ok)
print("Training Dataset (NOK) for all the parts: ", train_nok)
# Out:
# cuda
# train dataset:  45103
# Training Dataset for all the parts:  [5188, 6078, 5238, 5188, 2595, 5188, 5413, 5041, 5174]
# Training Dataset (OK) for all the parts:  [4935, 5216, 4753, 4584, 2541, 4824, 4882, 4879, 4805]
# Training Dataset (NOK) for all the parts:  [253, 862, 485, 604, 54, 364, 531, 162, 369]

# %%
import torch

import random
torch.manual_seed(17)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)


DATA_DIR = f'/home/woody/iwfa/iwfa011h/Fangjun_Wang_2021_MBH-dataset/MBH-dataset/Labels/Main_Labels/'

lines = []
## Training Test
with open(DATA_DIR + "test.txt") as f:
    lines = [line for line in f]

print("Test dataset: ", len(lines))

### getting only Part A training data

test_lines = []
test_ok = []
test_nok = []

j = 0
temp = []
temp1 = []
temp2 = []
while (j <=8):
    for i in range(len(lines)):
        temp_str = str(lines[i]).split()
        img_name = temp_str[0]
        img_folder = temp_str[1]
        label = int(temp_str[2])

        # print(img_name)
        # print(img_folder)
        # print(label)
        if j==0:
            if img_folder == "Part-0002" or img_folder == "Part-0003":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j ==1:
            if img_folder == "Part-0004" or img_folder == "Part-0005":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==2:
            if img_folder == "Part-0006" or img_folder == "Part-0007":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j ==3:
            if img_folder == "Part-0012" or img_folder == "Part-0013":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==4:
            if img_folder == "Part-0014":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==5:
            if img_folder == "Part-0015" or img_folder == "Part-0016":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==6:
            if img_folder == "Part-0017" or img_folder == "Part-0020":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==7:
            if img_folder == "Part-0018" or img_folder == "Part-0021":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])
        elif j==8:
            if img_folder == "Part-0019" or img_folder == "Part-0022":
                temp.append(lines[i])
                if label ==0:
                    temp1.append(lines[i])
                else:
                    temp2.append(lines[i])

    test_lines.append(len(temp))
    test_ok.append(len(temp1))
    test_nok.append(len(temp2))
    j+=1
    temp = []
    temp1 = []
    temp2=[]


print("Test Dataset for all the parts: ", test_lines)
print("Test Dataset (OK) for all the parts: ", test_ok)
print("Test Dataset (NOK) for all the parts: ", test_nok)
# Out:
# cuda
# Test dataset:  6800
# Test Dataset for all the parts:  [800, 800, 800, 800, 400, 800, 800, 800, 800]
# Test Dataset (OK) for all the parts:  [600, 600, 599, 600, 300, 600, 601, 600, 600]
# Test Dataset (NOK) for all the parts:  [200, 200, 201, 200, 100, 200, 199, 200, 200]
